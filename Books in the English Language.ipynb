# %%
from stcn import *
import json
from collections import Counter

# %%
query = '''

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX kb: <http://data.bibliotheken.nl/def#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT * WHERE {
# ?title schema:mainEntityOfPage ?mainEntity .
# ?mainEntity schema:isPartOf <http://data.bibliotheken.nl/id/dataset/stcn>  . 

# ?title schema:inLanguage 'en' .

} 

'''

df = run_query(query)
print( f'There {df.drop_duplicates(subset="title.value", keep="last").shape[0]} English titles in the STCN.')
# Out:
# There 1299 English titles in the STCN.

# %%
query = '''

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX kb: <http://data.bibliotheken.nl/def#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT * WHERE {
# ?resource schema:mainEntityOfPage ?mainEntity .
# ?mainEntity schema:isPartOf <http://data.bibliotheken.nl/id/dataset/stcn>  . 

# ?resource schema:inLanguage 'ang' .

OPTIONAL {
# ?resource schema:name ?title . }

OPTIONAL {
# ?resource schema:author ?author_node . 
# ?author_node schema:author ?author_info .
# ?author_info  rdfs:label ?author_name . }

}

'''

oe_df = run_query(query)
print( f'There {oe_df.drop_duplicates(subset="title.value", keep="last").shape[0]} Old English titles in the STCN.')
# Out:
# There 5 Old English titles in the STCN.

# %% [markdown]
# ## Titles in English

# %% [markdown]
# The cell below requests more detailed metadata about the titles in English.

# %%
query = '''

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX kb: <http://data.bibliotheken.nl/def#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT * WHERE {

# ?resource schema:mainEntityOfPage ?mainEntity .
# ?mainEntity schema:isPartOf <http://data.bibliotheken.nl/id/dataset/stcn>  . 

# ?resource schema:inLanguage 'en' .
# ?resource schema:publication ?publ .


# ?resource schema:name ?title . 

OPTIONAL {
# ?resource schema:alternateName ?alt_title . }

OPTIONAL {
# ?resource schema:author ?author_node . 
# ?author_node schema:author ?author_info .
# ?author_info  rdfs:label ?author_name . }

OPTIONAL {
# ?resource schema:inLanguage ?language . }


OPTIONAL {
# ?publ schema:startDate ?publ_year . 
# ?publ schema:description ?imprint . 
# ?publ schema:publishedBy ?publisher . 
# ?publisher schema:name ?publ_name .
# ?publisher schema:location ?location_node .
# ?location_node schema:address ?address .
# ?address schema:addressLocality ?place . 
}

OPTIONAL { 
# ?resource schema:about ?subject .
# ?subject skos:prefLabel ?subject_label .
} 


}

'''

df = run_query(query)

print(df.shape)
print(df.columns)
# Out:
# (3938, 36)
# Index(['resource.type', 'resource.value', 'mainEntity.type',
#        'mainEntity.value', 'publ.type', 'publ.value', 'title.type',
#        'title.value', 'alt_title.type', 'alt_title.value', 'author_node.type',
#        'author_node.value', 'author_info.type', 'author_info.value',
#        'author_name.type', 'author_name.value', 'language.type',
#        'language.value', 'publ_year.type', 'publ_year.value', 'imprint.type',
#        'imprint.value', 'publisher.type', 'publisher.value', 'publ_name.type',
#        'publ_name.value', 'location_node.type', 'location_node.value',
#        'address.type', 'address.value', 'place.type', 'place.value',
#        'subject.type', 'subject.value', 'subject_label.type',
#        'subject_label.value'],
#       dtype='object')

# %% [markdown]
# ## Create JSON
#
# To make the analysis easier, the metadata are converted to JSON

# %%
import numpy as np

topics_dict = dict()


def read_topics():
    topics_dict = dict()
    topics = pd.read_excel('Topics.xlsx')
    for i,row in topics.iterrows():
        topics_dict[ row['topic'] ] = row['group']
    return topics_dict
    

def cluster_subject(subject):
    
    global topics_dict
    
    if not topics_dict:
        topics_dict = read_topics()
    
    if not(pd.isna(subject)):    
        return topics_dict[subject]
    else:
        return np.nan

topics_dict = read_topics()
    
df['subject_cluster'] = df['subject_label.value'].apply(cluster_subject)


def year_publication(year_str):
    if re.search( r'\d{4}' , str(year_str) ):
        return int(year_str)
    else:
        return np.nan
    
df['year'] = df['publ_year.value'].apply(year_publication)

# %%
unique_ids = df.sort_values('year')['resource.value'].unique()

data = []

def print_value(value):
    if pd.isna(value):
        return ''
    else:
        return value
    
def get_values(df,field,fields_dict):
    rows = df.drop_duplicates(field)
    all_rows = []
    for i,row in rows.iterrows():
        values = dict()
        for f in fields_dict:
            values[fields_dict[f]] = print_value(row[f])
        all_rows.append(values)
    return all_rows    

for resource in unique_ids:
    record = dict()
    record['ppn'] = resource
    #print(resource)

    df_resource = df[ df['resource.value'] == resource ]
    
    record['title'] = df_resource.iloc[0]['title.value']
    record['alternative_title'] = df_resource.iloc[0]['alt_title.value']
    record['year'] = df_resource.iloc[0]['publ_year.value']
    
    ## Publishers
    unique_id = 'publisher.value'
    fields_dict = { 'publisher.value':'ppn',
        'publ_name.value':'name'
        #'place.value':'place'
    }
    
    all_publishers = get_values(df_resource,unique_id,fields_dict)
    record['publishers'] = all_publishers

    ## Subjects
    unique_id = 'subject.value'
    fields_dict = {'subject.value':'ppn',
              'subject_label.value':'label',
               'subject_cluster':'group' }
    all_subjects = get_values(df_resource,unique_id,fields_dict)
    record['subjects'] = all_subjects
    
    ## Authors
    unique_id = 'author_info.value'
    fields_dict = {'author_info.value':'ppn',
              'author_name.value':'name' }
    all_authors = get_values(df_resource,unique_id,fields_dict)
    record['authors'] = all_authors
    
    ## Languages
    unique_id = 'language.value'
    fields_dict = {'language.value':'code' }
    all_languages = get_values(df_resource,unique_id,fields_dict)
    record['languages'] = all_languages
    
    data.append(record)
    
with open('english_titles.json','w',encoding='utf-8') as out:
    out.write(json.dumps(data,indent=4))

# %%
f = open('english_titles.json')
json_data = json.load(f)
f.close()

# %% [markdown]
# ## Bibles

# %%
count = 0 

for book in json_data:
    #print(book['title'])
    if re.search( 'geneva', str(book['alternative_title']) , re.IGNORECASE):
        count += 1
        print(f"{book['ppn']}\n{book['title']}\n{book['year']}")
        print({book['alternative_title']})
        for publ in book['publishers']:
            print(publ['name'])
        print('\n\n')
print(count)
# Out:
# http://data.bibliotheken.nl/id/nbt/p320837467
# The CL. psalmes of David in prose and meter. For the vse of the Kirk of Scotland
# 1601
# {'Bible English Geneva'}
# Hart, Andrew
# Charteris, Henry (heirs)
# Canin, Abraham
#
#
#
# http://data.bibliotheken.nl/id/nbt/p265019737
# The New Testament of ovr Lord Iesvs Christ.
# 1601
# {'Bible English Geneva'}
# Charteris, Henry (heirs)
# Hart, Andrew
# Canin, Isaac Jansz
#
#
#
# http://data.bibliotheken.nl/id/nbt/p335881874
# The Bible, that is, The holy Scriptures conteined in the Olde and Newe Testament
# 1633
# {'Bible English Geneva'}
# Stam, Jan Fredericksz
# Craffort, Thomas
#
#
#
# http://data.bibliotheken.nl/id/nbt/p335875777
# The Bible, that is, The holy Scriptures conteined in the Olde and Newe Testament
# 1633
# {'Bible English Geneva'}
# Barker, Christopher (deputies of)
# Stam, Jan Fredericksz
#
#
#
# http://data.bibliotheken.nl/id/nbt/p08720021X
# The Bible: that is, The Holy Scriptvres contained in the Old and New Testament
# 1640
# {'Bible English Geneva'}
# Stafford, Thomas
# Boxe, Willem Christiaens van der
#
#
#
# http://data.bibliotheken.nl/id/nbt/p204380820
# The Bible. That is, The Holy Scriptvres contained in the Old and New Testament
# 1644
# {'Bible English Geneva'}
# Stafford, Thomas
# Boxe, Willem Christiaens van der
#
#
#
# http://data.bibliotheken.nl/id/nbt/p205187242
# The Bible: that is, The Holy Scriptvres contained in the Old and New Testament
# 1644
# {'Bible English Geneva'}
# Boxe, Willem Christiaens van der
# Stafford, Thomas
#
#
#
# http://data.bibliotheken.nl/id/nbt/p101397054
# Le Nouveau Testament. C'est a dire La Nouvelle Alliance de nostre Seigneur Iesus Christ.
# 1684
# {'Bible Polyglot Geneva, King James and Statenvertaling (French, English and Dutch) '}
# Swart, Steven (wed.)
# Oossaan, Aart Dircksz
# Deyster, Jacobus van der
#
#
#
# http://data.bibliotheken.nl/id/nbt/p204350484
# Le Nouveau Testament, c'est-a-dire La Nouvelle Alliance de nostre Seigneur Jesus-Christ [...].
# 1700
# {'Bible Polyglot Geneva and King James (French and English)'}
# Swart, Steven (wed.)
#
#
#
# http://data.bibliotheken.nl/id/nbt/p330631349
# The Bible, that is, the Holy Scriptures conteined in the Olde and Newe Testament
# 16XX
# {'Bible English Geneva'}
# Stam, Jan Fredericksz
# Barker, Christopher (deputies of)
#
#
#
# http://data.bibliotheken.nl/id/nbt/p335998666
# The Bible, that is, The Holy Scriptures conteined in the Olde and Newe Testament
# 16XX
# {'Bible English Geneva'}
# Stam, Jan Fredericksz
# Barker, Christopher (deputies of)
#
#
#
# http://data.bibliotheken.nl/id/nbt/p264128737
# The Bible that is, The Holy Scriptures conteined in the Olde and Newe Testament
# 16XX
# {'Bible English Geneva'}
# Barker, Christopher (deputies of)
#
#
#
# http://data.bibliotheken.nl/id/nbt/p29629263X
# The New Testament of our Lord Iesvs Christ.
# 16XX
# {'Bible English Geneva'}
# Stam, Jan Fredericksz
# Barker, Christopher (deputies of)
#
#
#
# http://data.bibliotheken.nl/id/nbt/p37141492X
# The Bible, that is, The Holy Scriptures conteined in the Olde and Newe Testament
# 16XX
# {'Bible English Geneva'}
# Barker, Christopher (deputies of)
# Stam, Jan Fredericksz
#
#
#
# 14

# %% [markdown]
# ## Average number of books per year

# %%
years = Counter()

for book in json_data:
    years.update([book['year']])
        
for year,count in years.most_common():
    print(year,count)
        
print(sum(years.values()))
# Out:
# nan 96
# 17XX 79
# 1640 28
# 1638 26
# 1688 24
# 16XX 20
# 1624 18
# 1637 17
# 1649 17
# 1687 14
# 1712 14
# 1609 13
# 1639 13
# 1652 13
# 1644 12
# 1682 12
# 1686 12
# 1689 12
# 1635 11
# 1675 11
# 1678 11
# 1711 11
# 1720 11
# 1604 10
# 1619 10
# 1620 10
# 1621 10
# 1622 10
# 1750 10
# 1605 9
# 1610 9
# 1615 9
# 1650 9
# 1673 9
# 1677 9
# 1590 8
# 1602 8
# 1617 8
# 1618 8
# 1636 8
# 1672 8
# 1710 8
# 1719 8
# 1721 8
# 1752 8
# 1599 7
# 1608 7
# 1625 7
# 1629 7
# 1641 7
# 1643 7
# 1651 7
# 1660 7
# 1680 7
# 1683 7
# 1691 7
# 1692 7
# 1718 7
# 1728 7
# 1738 7
# 1765 7
# 163X 7
# 1597 6
# 1616 6
# 1623 6
# 1628 6
# 1630 6
# 1633 6
# 1634 6
# 1646 6
# 1659 6
# 1661 6
# 1663 6
# 1684 6
# 1727 6
# 1730 6
# 1740 6
# 1754 6
# 1759 6
# 1586 5
# 1611 5
# 1626 5
# 1631 5
# 1632 5
# 1645 5
# 1648 5
# 1662 5
# 1664 5
# 1700 5
# 1731 5
# 1735 5
# 1772 5
# 1784 5
# 179X 5
# 170X 5
# 1588 4
# 1600 4
# 1601 4
# 1606 4
# 1607 4
# 1614 4
# 1653 4
# 1654 4
# 1657 4
# 1679 4
# 1685 4
# 1690 4
# 1695 4
# 1697 4
# 1698 4
# 1716 4
# 1725 4
# 1732 4
# 1741 4
# 1751 4
# 1764 4
# 1782 4
# 1581 3
# 1582 3
# 1584 3
# 1585 3
# 1589 3
# 1598 3
# 1603 3
# 1642 3
# 1647 3
# 1655 3
# 1658 3
# 1666 3
# 1676 3
# 1703 3
# 1722 3
# 1724 3
# 1726 3
# 1733 3
# 1737 3
# 1744 3
# 1745 3
# 1747 3
# 1748 3
# 1749 3
# 1753 3
# 1763 3
# 1774 3
# 1792 3
# 1793 3
# 1794 3
# 1797 3
# 160X 3
# 1592 2
# 1593 2
# 1594 2
# 1612 2
# 1613 2
# 1656 2
# 1667 2
# 1669 2
# 1670 2
# 1671 2
# 1681 2
# 1701 2
# 1702 2
# 1705 2
# 1706 2
# 1708 2
# 1723 2
# 1729 2
# 1734 2
# 1736 2
# 1760 2
# 1762 2
# 1766 2
# 1771 2
# 1776 2
# 1778 2
# 1786 2
# 1787 2
# 1790 2
# 1791 2
# 1795 2
# 1798 2
# 164X 2
# 168X 2
# 172X 2
# 162X 2
# 173X 2
# 159X 2
# 166X 2
# 158X 2
# 161X 2
# 1569 1
# 1574 1
# 1576 1
# 1583 1
# 1587 1
# 1591 1
# 1595 1
# 1596 1
# 1627 1
# 1665 1
# 1668 1
# 1674 1
# 1693 1
# 1694 1
# 1696 1
# 1699 1
# 1704 1
# 1707 1
# 1713 1
# 1714 1
# 1715 1
# 1717 1
# 1739 1
# 1742 1
# 1758 1
# 1761 1
# 1767 1
# 1768 1
# 1770 1
# 1773 1
# 1775 1
# 1777 1
# 1780 1
# 1783 1
# 1788 1
# 1789 1
# 1796 1
# 1799 1
# 165X 1
# 176X 1
# 178X 1
# 180X 1
# 15XX 1
# 1299

# %%
print(min(years.keys()))
print(max(years.keys()))

print(int(max(years.keys()))-int(min(years.keys())))

## All books

years = Counter()

for book in json_data:
    years.update([book['year']])
    
total = sum(years.values())
print(total)
print(len(years.keys()))
print(total/len(years.keys()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nf/35gdwksd0fx8kzbsljz4dz6hnrcnxq/T/ipykernel_93437/3198199057.py in <module>
# ----> 1 print(min(years.keys()))
#       2 print(max(years.keys()))
#       3
#       4 print(int(max(years.keys()))-int(min(years.keys())))
#       5
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
for book in json_data:
    if not pd.isna(book['year']) and re.search( r'\d{4}' , book['year']):
        if int(book['year']) == 1638: 
            print(f"{book['ppn']}\n{book['title']}\n{book['year']}")
            for publ in book['publishers']:
                print(publ['name'])
            print('\n\n')
    
print(count)

# %% [markdown]
# ## List of all titles

# %%
count = 0
for book in json_data:
    print(f"{book['ppn']}\n{book['title']}\n{book['year']}\n\n")
    count += 1
        
print(count)
# Out:
# http://data.bibliotheken.nl/id/nbt/p424370913
# Exercitatio alphabetica nova et utilissima, variis expressa lingvis et characteribvs.
# 1569
#
#
# http://data.bibliotheken.nl/id/nbt/p344098192
# Certayne newes of the whole discription, ayde, and helpe of the christian princes and nobles, the vvhich for the comfort and deliuerance of the poore Christians in the low Countries, are gathered together.
# 1574
#
#
# http://data.bibliotheken.nl/id/nbt/p409609145
# Colloqves ov dialogves avec vn dictionaire en six langues: flamen, anglois, alleman, françois, espaignol, & italien [...].
# 1576
#
#
# http://data.bibliotheken.nl/id/nbt/p832930423
# The apologie or defence, of [...] prince William [...] prince of Orange [...] against the proclamation [...] by the king of Spaine
# 1581
#
#
# http://data.bibliotheken.nl/id/nbt/p298780496
# The apologie or defence, of [...] prince William [...] prince of Orange [...] against the proclamation [...] by the king of Spaine
# 1581
#
#
# http://data.bibliotheken.nl/id/nbt/p264085450
# A pleasavnt dialogve, betweene a souldior of Barwicke, and an English chaplaine. Wherein are [...] laide open, such reasons as are brought in for maintenaunce of popishe traditions in our Eng. church.
# 1581
#
#
# http://data.bibliotheken.nl/id/nbt/p230413285
# A booke which sheweth the life and manners of all true christians.
# 1582
#
#
# http://data.bibliotheken.nl/id/nbt/p230413692
# A booke which sheweth the life and manners of all true christians.
# 1582
#
#
# http://data.bibliotheken.nl/id/nbt/p320744841
# The first fovre bookes of Virgil his Aeneis.
# 1582
#
#
# http://data.bibliotheken.nl/id/nbt/p427864208
# A little treatise uppon the firste verse of the 122. psalm. Stirring vp vnto carefull desiring & dutifull labouring for true church gouernement.
# 1583
#
#
# http://data.bibliotheken.nl/id/nbt/p215124189
# The artes of logike and rethorike.
# 1584
#
#
# http://data.bibliotheken.nl/id/nbt/p425756092
# A treatise against the proclamation published by the king of Spayne.
# 1584
#
#
# http://data.bibliotheken.nl/id/nbt/p321705157
# The trve report of the lamentable death, of VVilliam of Nassawe prince of Orange: who was trayterouslie slayne with a dagge in his owne courte, by Balthazar Serack a Burgunian, the first of Iuly 1584.
# 1584
#
#
# http://data.bibliotheken.nl/id/nbt/p323402240
# Colloqves ov dialogves, avec vn dictionaire en quatre langues: flamen, anglois, françois, & latin.
# 1585
#
#
# http://data.bibliotheken.nl/id/nbt/p23514374X
# The explanation. Of the trve and lavvfvll right and tytle, of [...] Anthonie [...] king of Portugall, concerning his warres, againste Phillip king of Castile [...] for the recouerie of his kingdome.
# 1585
#
#
# http://data.bibliotheken.nl/id/nbt/p213306654
# The explanation. Of the trve and lavvfvll right and tytle, of [...] Anthonie [...] king of Portugall, concerning his warres, againste Phillip king of Castile [...] for the recouerie of his kingdome.
# 1585
#
#
# http://data.bibliotheken.nl/id/nbt/p391733796
# A booke of the forme of common prayers, administration of the sacraments, &c. agreable to Gods worde, and the vse of the reformed churches
# 1586
#
#
# http://data.bibliotheken.nl/id/nbt/p114615950
# A choice of emblemes, and other devises.
# 1586
#
#
# http://data.bibliotheken.nl/id/nbt/p323409628
# Lavves and ordinances militarie, sett downe and established by [...] Robert earle of Leycester
# 1586
#
#
# http://data.bibliotheken.nl/id/nbt/p235706833
# A defence of the reasons of the counter-poyson, for maintenance of the eldership, against an aunsvvere made to them by doctor Copequot in a publike sermon [...] vpon psal. 84
# 1586
#
#
# http://data.bibliotheken.nl/id/nbt/p840446616
# The honovrable repvtation of a sovldier.
# 1586
#
#
# http://data.bibliotheken.nl/id/nbt/p215132610
# A defence of the godlie ministers, against the slaunders of D. Bridges, contayned in his ansvvere to the preface before the discourse of ecclesiasticall gouernement.
# 1587
#
#
# http://data.bibliotheken.nl/id/nbt/p215132335
# A defence of the ecclesiastical discipline ordayned of God [...]. Against a replie of maister Bridges [...]. Which replie he termeth, A defence of the gouernment established in the Church of Englande, for ecclesiasticall matters.
# 1588
#
#
# http://data.bibliotheken.nl/id/nbt/p344098729
# The humble petition of the communaltie to their most renovvned and gracious soueraigne, the Ladie Elizabeth
# 1588
#
#
# http://data.bibliotheken.nl/id/nbt/p430971532
# The artes of logike and rethorike.
# 1588
#
#
# http://data.bibliotheken.nl/id/nbt/p430971524
# The vvhole doctrine of the Sacramentes, plainlie and fullie set dovvne and declared out of the word of God.
# 1588
#
#
# http://data.bibliotheken.nl/id/nbt/p427501490
# Colloqvia et dictionariolvm septem lingvarvm, Belgicæ, Anglicæ, Tectonicæ; Latinæ, Italicæ, Hispanicæ, Gallicæ [...].
# 1589
#
#
# http://data.bibliotheken.nl/id/nbt/p33061178X
# A trve description ovt of the vvorde of God, of the visible chvrch.
# 1589
#
#
# http://data.bibliotheken.nl/id/nbt/p330612352
# A trve description ovt of the vvorde of God, of the visible chvrch.
# 1589
#
#
# http://data.bibliotheken.nl/id/nbt/p326789537
# An answere to George Giffords pretended defence of read praiers and deuised litourgies.
# 1590
#
#
# http://data.bibliotheken.nl/id/nbt/p330611941
# A collection of certaine sclavnderovs articles gyuen out by the bisshops against such faithfull christians as they now vniustly deteyne.
# 1590
#
#
# http://data.bibliotheken.nl/id/nbt/p326786961
# A collection of certain letters and conferences lately passed betvvixt certaine preachers & tvvo prisoners in the Fleet.
# 1590
#
#
# http://data.bibliotheken.nl/id/nbt/p433000465
# A briefe and necessarie catachisme[!] or instrvcion.
# 1590
#
#
# http://data.bibliotheken.nl/id/nbt/p433000457
# Two godly sermons. The first preached before the Queenes maiestie [...]. The other preached in the Tower of London.
# 1590
#
#
# http://data.bibliotheken.nl/id/nbt/p321360427
# A brief discoverie of the false chvrch.
# 1590
#
#
# http://data.bibliotheken.nl/id/nbt/p402317920
# Maister Derings workes
# 1590
#
#
# http://data.bibliotheken.nl/id/nbt/p344455777
# A short and profitable treatise, of lavvfull and vnlavvfull recreations, and of the right vse and abvse of those that are lawefull.
# 1590
#
#
# http://data.bibliotheken.nl/id/nbt/p427501687
# Colloqvia et dictionariolvm septem lingvarvm, Belgicæ, Anglicæ, Tevtonicæ; Latinæ, Italicæ, Hispanicæ, Gallicæ [...].
# 1591
#
#
# http://data.bibliotheken.nl/id/nbt/p408752246
# Colloqvia et dictionariolvm septem lingvarvm, Belgicæ, Anglicæ, Tevtonicæ; Latinæ, Italicæ, Hispanicæ, Gallicæ [...].
# 1592
#
#
# http://data.bibliotheken.nl/id/nbt/p266959083
# A petition directed to her most excellent maiestie, wherein is deliuered [...] a meane howe to compound the ciuill dissention in the church of England.
# 1592
#
#
# http://data.bibliotheken.nl/id/nbt/p235704806
# Colloqvia et dictionariolvm septem lingvarvm, Belgicæ, Anglicæ, Tevtonicæ, Latinæ, Italicæ, Hispanicæ, Gallicæ [...].
# 1593
#
#
# http://data.bibliotheken.nl/id/nbt/p097751413
# Mafteaẖ lešon ha-qodeš that is The key of the holy tongve.
# 1593
#
#
# http://data.bibliotheken.nl/id/nbt/p428404790
# The defence of Iob Throkmorton, against the slaunders of maister Sutcliffe
# 1594
#
#
# http://data.bibliotheken.nl/id/nbt/p831160373
# The Song of songs.
# 1594
#
#
# http://data.bibliotheken.nl/id/nbt/p326741712
# A treatise of the ministery of the church of England. Wherein is handled this question, whether it be to be separated from, or joyned vnto.
# 1595
#
#
# http://data.bibliotheken.nl/id/nbt/p235703788
# A brief apologie of Thomas Cartwright against all such slaunderous accusations as it pleaseth Mr. Sutcliffe [...] to loade him with.
# 1596
#
#
# http://data.bibliotheken.nl/id/nbt/p338764453
# Theologicall axioms or conclvsions: pvblikly controverted, discvssed, and conclvded by that poore English congregation, in Amstelredam.
# 1597
#
#
# http://data.bibliotheken.nl/id/nbt/p427501709
# Colloqvia et dictionariolvm septem lingvarvm, Belgicæ, Anglicæ, Tevtonicæ, Latinae, Italicae, Hispanicae, Gallicae [...].
# 1597
#
#
# http://data.bibliotheken.nl/id/nbt/p07941026X
# Bibliotheca theologica: or, A librarye theological.
# 1597
#
#
# http://data.bibliotheken.nl/id/nbt/p32674228X
# An epistle to the learned nobilitie of England. Touching translating the Bible from the original.
# 1597
#
#
# http://data.bibliotheken.nl/id/nbt/p215132084
# An epistle to the learned nobilitie of England. Touching translating the Bible from the original.
# 1597
#
#
# http://data.bibliotheken.nl/id/nbt/p427864011
# Theoriqve and practise of warre.
# 1597
#
#
# http://data.bibliotheken.nl/id/nbt/p423315293
# The recantation of maister Patrik Adamsone, sometime archbishop of Saint-Androwes in Scotlande
# 1598
#
#
# http://data.bibliotheken.nl/id/nbt/p264637011
# A treatise of the svfferings and victory of Christ.
# 1598
#
#
# http://data.bibliotheken.nl/id/nbt/p327262877
# The Frenche chirurgerye, or all the manualle operations of chirurgerye.
# 1598
#
#
# http://data.bibliotheken.nl/id/nbt/p266966721
# A defence of the chvrches and ministery of Englande [...] against the reasons and obiections of [...] Francis Iohnson, and others [...] commonly called Brownists.
# 1599
#
#
# http://data.bibliotheken.nl/id/nbt/p121540928
# A placarde or statute concerning the musters whereby to prevent al frawde used by the not-keeping of the compagnies full
# 1599
#
#
# http://data.bibliotheken.nl/id/nbt/p330612689
# An apologie, or defence of the possession of William Sommers, a yong[!] man of the towne of Nottingham.
# 1599
#
#
# http://data.bibliotheken.nl/id/nbt/p05600415X
# The boock of physicke.
# 1599
#
#
# http://data.bibliotheken.nl/id/nbt/p326787283
# A christian letter of certaine English protestants, vnfained fauourers of the present state of religion, authorised and professed in England: vnto [...] mr R. Hoo. requiring resolution in certaine matters of doctrine
# 1599
#
#
# http://data.bibliotheken.nl/id/nbt/p42862717X
# The triall of maist. Dorrell, or A collection of defences against allegations not yet suffered to receiue convenient answere.
# 1599
#
#
# http://data.bibliotheken.nl/id/nbt/p330611305
# A triall of svbscription, by way of a preface vnto cartaine svbscribers; and, reasons for lesse rigour against non-subscribers.
# 1599
#
#
# http://data.bibliotheken.nl/id/nbt/p427864119
# A true discourse concerning the certaine possession and dispossession of 7 persons in one familie in Lancashire.
# 1600
#
#
# http://data.bibliotheken.nl/id/nbt/p326736972
# A defence of a treatise tovching the svfferings and victorie of Christ in the worke of ovr redemption.
# 1600
#
#
# http://data.bibliotheken.nl/id/nbt/p330612107
# An answer to maister H. Iacob his defence of the churches and ministery of England.
# 1600
#
#
# http://data.bibliotheken.nl/id/nbt/p427864100
# A true discourse concerning the certaine possession and dispossessiō of 7 persons in one familie in Lancashire.
# 1600
#
#
# http://data.bibliotheken.nl/id/nbt/p320838269
# The psalmes of Dauid in metre, with divers notes, and tunes augmented to them.
# 1601
#
#
# http://data.bibliotheken.nl/id/nbt/p320837467
# The CL. psalmes of David in prose and meter. For the vse of the Kirk of Scotland
# 1601
#
#
# http://data.bibliotheken.nl/id/nbt/p265019737
# The New Testament of ovr Lord Iesvs Christ.
# 1601
#
#
# http://data.bibliotheken.nl/id/nbt/p266561381
# A treatise of commerce, wherin are shewed the commodies[!] arising by a wel ordered [...] trade.
# 1601
#
#
# http://data.bibliotheken.nl/id/nbt/p256349517
# Certayne letters, translated into English, being first written in Latine. Two, by [...] Francis Iunius [...]. The other, by the exiled English church, abiding [...] at Amsterdam
# 1602
#
#
# http://data.bibliotheken.nl/id/nbt/p252263227
# An antiqvodlibet, or an advertisement to beware of secular priests.
# 1602
#
#
# http://data.bibliotheken.nl/id/nbt/p321976142
# The psalmes of David in metre, with divers notes, and tunes augmented to them
# 1602
#
#
# http://data.bibliotheken.nl/id/nbt/p317626140
# The CL. psalmes of David in meter, with the prose. For the vse of the kirk of Scotland
# 1602
#
#
# http://data.bibliotheken.nl/id/nbt/p260376663
# A booke of the forme of common prayers, administration of the sacraments, &c. agreeable to Gods worde, and the vse of the reformed churches
# 1602
#
#
# http://data.bibliotheken.nl/id/nbt/p261794981
# The psalmes of David in metre, with divers notes, and tunes augmented to them
# 1602
#
#
# http://data.bibliotheken.nl/id/nbt/p30198669X
# The plea of the innocent: wherein is auerred; that the ministers & people falslie termed puritanes, are iniuriouslie slaundered for enemies or troublers of the state.
# 1602
#
#
# http://data.bibliotheken.nl/id/nbt/p324960425
# The plea of the innocent: wherein is auerred; that the ministers & people falslie termed puritanes, are iniuriouslie slaundered for enemies or troublers of the state.
# 1602
#
#
# http://data.bibliotheken.nl/id/nbt/p330631934
# A discourse of some troubles, and excommunications in the banished English church at Amsterdam.
# 1603
#
#
# http://data.bibliotheken.nl/id/nbt/p119509725
# A trevve description of the nobill race of the Stevvards
# 1603
#
#
# http://data.bibliotheken.nl/id/nbt/p262029650
# Declaration of generall corruption of religion, scripture and all learning; wrought by D. Bilson.
# 1603
#
#
# http://data.bibliotheken.nl/id/nbt/p267341504
# Two little workes defensive of our redemption.
# 1604
#
#
# http://data.bibliotheken.nl/id/nbt/p268626979
# An assertion for true and christian church-policie.
# 1604
#
#
# http://data.bibliotheken.nl/id/nbt/p253705983
# An advertisement of corrvption in ovr handling of religion.
# 1604
#
#
# http://data.bibliotheken.nl/id/nbt/p255770464
# A treatise of divine worship, tending to prove that the ceremonies imposed vpon the ministers [...] in England [...] are in their vse vnlawfull.
# 1604
#
#
# http://data.bibliotheken.nl/id/nbt/p252087917
# Declaration of generall corruption of religion, Scripture and all learning; wrought by D. Bilson.
# 1604
#
#
# http://data.bibliotheken.nl/id/nbt/p327054409
# An apologie or defence of such true christians as are commonly (but vniustly) called Brownists.
# 1604
#
#
# http://data.bibliotheken.nl/id/nbt/p249327538
# A shorte treatise, of the crosse in baptisme contracted into this syllogisme.
# 1604
#
#
# http://data.bibliotheken.nl/id/nbt/p216240204
# Two little workes defensiue of our redemption.
# 1604
#
#
# http://data.bibliotheken.nl/id/nbt/p256349657
# Reasons taken ovt of Gods word and the best hvmane testimonies proving a necessitie of reforming ovr chvrches in England.
# 1604
#
#
# http://data.bibliotheken.nl/id/nbt/p326743855
# An apologie or defence of svch trve christians as are commonly (but vniustly) called Brovvnists.
# 1604
#
#
# http://data.bibliotheken.nl/id/nbt/p252244818
# The familie of David, for the sonnes of the kingdome, vvith a chronicle vnto the redemtion.
# 1605
#
#
# http://data.bibliotheken.nl/id/nbt/p323172881
# A comment vpon Coheleth, or, Ecclesiastes.
# 1605
#
#
# http://data.bibliotheken.nl/id/nbt/p12048272X
# A comment vpon Coheleth, or, Ecclesiastes.
# 1605
#
#
# http://data.bibliotheken.nl/id/nbt/p330632566
# A replie vpon the R.R.F. Th. VVinton for heads of his divinity in his sermon and svrvey.
# 1605
#
#
# http://data.bibliotheken.nl/id/nbt/p326738355
# An advertisement of corrvption in ovr handling of religion.
# 1605
#
#
# http://data.bibliotheken.nl/id/nbt/p326805109
# Twelve generall arguments, proving that the ceremonies imposed upon the ministers of the gospell in England, by our prelates, are unlawfull .
# 1605
#
#
# http://data.bibliotheken.nl/id/nbt/p326743022
# Certaine considerations drawne from the canons of the last sinod, and other the kings ecclesiasticall and statute law
# 1605
#
#
# http://data.bibliotheken.nl/id/nbt/p326738630
# Anexplication[!] of the article katêlthen eis adô of our Lordes soules going from his body to paradise [...] vvith a defense of the Q. of Englands religion.
# 1605
#
#
# http://data.bibliotheken.nl/id/nbt/p166715158
# Certaine demandes with their grounds, drawne out of holy writ, and propounded in foro conscientiæ by some religious gen̄tl.
# 1605
#
#
# http://data.bibliotheken.nl/id/nbt/p326800859
# The lamentationes of Ieremy.
# 1606
#
#
# http://data.bibliotheken.nl/id/nbt/p249328852
# The remoouall of certaine imputations laid vpon the ministers of Deuon: and Cornwall by one M.T.H
# 1606
#
#
# http://data.bibliotheken.nl/id/nbt/p330611534
# A plaine refvtation of M. Giffards booke, intituled, Ashort[!] treatise gainst the donatistes of England.
# 1606
#
#
# http://data.bibliotheken.nl/id/nbt/p330611089
# The familie of David, for the sonnes of the kingdome, with a chronicle vnto the redemtion.
# 1606
#
#
# http://data.bibliotheken.nl/id/nbt/p85107989X
# The exercise of armes for calivres, muskettes, and pikes.
# 1607
#
#
# http://data.bibliotheken.nl/id/nbt/p330632957
# The confession of faith of certayn English people, living in exile, in the Low countreyes.
# 1607
#
#
# http://data.bibliotheken.nl/id/nbt/p253703417
# The commvnion of saincts, a treatise of the fellowship that the faithful have with God.
# 1607
#
#
# http://data.bibliotheken.nl/id/nbt/p250232766
# A scholasticall discovrse against symbolizing with antichrist in ceremonies.
# 1607
#
#
# http://data.bibliotheken.nl/id/nbt/p249329158
# Ovr Lordes famile[!] and many other poinctes depending vpon it.
# 1608
#
#
# http://data.bibliotheken.nl/id/nbt/p256328528
# Covnterpoyson. Considerations touching the points in difference between the godly ministers & people of the Church of England, and the seduced brethren of the separation.
# 1608
#
#
# http://data.bibliotheken.nl/id/nbt/p256362939
# Certayne reasons and arguments proving that it is not lawfull to heare or have any spirituall communion with the present ministerie of the church of England.
# 1608
#
#
# http://data.bibliotheken.nl/id/nbt/p330632744
# A petition to the lords, to examine the religion and cariage of D. Ban. archb.
# 1608
#
#
# http://data.bibliotheken.nl/id/nbt/p357079175
# The exercise of armes for calivres, muskettes, and pikes.
# 1608
#
#
# http://data.bibliotheken.nl/id/nbt/p25635023X
# An epistle sent vnto tvvo daughters of VVarwick.
# 1608
#
#
# http://data.bibliotheken.nl/id/nbt/p298065134
# The lamentations of Ieremy.
# 1608
#
#
# http://data.bibliotheken.nl/id/nbt/p422853321
# Drie artiickelen aengaende de moderatie in de proceduyren van de inquisitie tegens de con. majesteyt van Engelants onderdanen; in Spanien
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p266563171
# Articles, of a treatie of trvce. Made and concluded in [...] Antvverp, the 9. of April 1609. betweene the [...] archdukes Albert and Isabella [...] with [...] the Estates Generall of the Vnited Prouinces
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p326739955
# A defence of the ivdgment of the reformed churches. That a man may lawfullie not onelie put awaie his wife for her adulterie, but also marrie another.
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p252088085
# A defence of the booke entitled A cōcent of Scripture, for amendment of former athean [...] errours.
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p328055328
# An ansvvere to a sermon preached the 17 of April anno D. 1608, by George Downame [...] intitvled, A sermon desendinge the honorable function of bishops [...] refuted
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p330610740
# The character of the beast: or The false constitvtion of the chvrch. Discovered in certayne passages betwixt mr. R. Clifton & Iohn Smyth, concerning true christian baptisme
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p298066246
# Principal positions for groundes of the holy Bible.
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p330635689
# A defence of the Holy Scriptures, worship, and ministerie, used in the christian churches [...] against the challenges [...] of mr. Smyth.
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p344360865
# A brief treatise conteyning some grounds and reasons, against two errours of the anabaptists.
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p860052400
# Dry artyckelen aengaende de moderatie in de procedueren van de inquisitie teghens de kon. majesteyt van Enghelants onderdanen; in Spagnien
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p169859541
# To the right high and mightie prince, Iames [...] king of great Britannie [...] an humble supplication for toleration and libertie.
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p832672726
# Drie artiickelen aengaende een moderatie te hebben in de proceduyren van de inquisitie tegens de con. maijesteyt van Engelants onderdanen; in Spanien
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p86005246X
# Dry artiickelen aengaende een moderatie te hebben in de proceduyren van de inquisitie teghens de con. majesteyt van Enghelants onderdanen in Spangien
# 1609
#
#
# http://data.bibliotheken.nl/id/nbt/p258191708
# The plea for infants and elder people, concerning their baptisme. Or a processe of the passages between M. Iohn Smyth and Richard Clyfton.
# 1610
#
#
# http://data.bibliotheken.nl/id/nbt/p34410480X
# A suruey of the Booke of Common Prayer
# 1610
#
#
# http://data.bibliotheken.nl/id/nbt/p256350736
# A ivstification of separation from the church of England. Against Mr Richard Bernard his invective, intitvled, The separatists schisme.
# 1610
#
#
# http://data.bibliotheken.nl/id/nbt/p298060477
# Iob.
# 1610
#
#
# http://data.bibliotheken.nl/id/nbt/p298061201
# A revelation of the holy apocalyps.
# 1610
#
#
# http://data.bibliotheken.nl/id/nbt/p256350477
# The divine beginning and institution of Christs true visible or ministeriall church.
# 1610
#
#
# http://data.bibliotheken.nl/id/nbt/p427501717
# Colloqvia et dictionariolvm septem lingvarvm, Belgicæ, Anglicæ, Tevtonicæ, Latinæ, Italicæ, Hispanicæ, Gallicæ [...].
# 1610
#
#
# http://data.bibliotheken.nl/id/nbt/p25819071X
# A plaine and cleere exposition of the second commandement.
# 1610
#
#
# http://data.bibliotheken.nl/id/nbt/p081636474
# A revelation of the holy apocalyps.
# 1610
#
#
# http://data.bibliotheken.nl/id/nbt/p260658685
# A dispvtation against the adoration of the reliques of saints departed.
# 1611
#
#
# http://data.bibliotheken.nl/id/nbt/p298066564
# A petition to the king. For avthority and allowance to expound the Apocalyps in Hebrew and Greek, to shew iewes and gentiles: that Rome in ce̜sars and pope, is therein still damned.
# 1611
#
#
# http://data.bibliotheken.nl/id/nbt/p264769252
# A revelation of the Apocalyps, that is the Apocalyps of S. Iohn illustrated vvith an analysis & scolions.
# 1611
#
#
# http://data.bibliotheken.nl/id/nbt/p258225688
# An arrow against idolatrie.
# 1611
#
#
# http://data.bibliotheken.nl/id/nbt/p26201338X
# A reqvire of agreement to the groundes of divinitie studie.
# 1611
#
#
# http://data.bibliotheken.nl/id/nbt/p260841889
# The book of psalmes.
# 1612
#
#
# http://data.bibliotheken.nl/id/nbt/p326792678
# A declaration and plainer opening of certain points, with a sovnd confirmation of some other, contained in a treatise intitvled, The divine beginning and institution of Christes true visible [...] church.
# 1612
#
#
# http://data.bibliotheken.nl/id/nbt/p256350353
# An animadversion to Mr Richard Clyftons Advertisement.
# 1613
#
#
# http://data.bibliotheken.nl/id/nbt/p255770626
# An attestation of many learned [...] divines iustifying this doctrine, viz. that the church-governement ought to bee alwayes with the peoples free consent.
# 1613
#
#
# http://data.bibliotheken.nl/id/nbt/p321361784
# The vnreasonablenesse of the separation. Made apparant, by an examination of mr. Iohnsons pretended reasons.
# 1614
#
#
# http://data.bibliotheken.nl/id/nbt/p057125481
# An learned commentarie vpon the revelation of Saint Iohn.
# 1614
#
#
# http://data.bibliotheken.nl/id/nbt/p258190868
# Of religions commvnion private, & publique.
# 1614
#
#
# http://data.bibliotheken.nl/id/nbt/p057125627
# A defence of the lawfvl calling of the ministers of reformed chvrches, against the cavillations of romanists.
# 1614
#
#
# http://data.bibliotheken.nl/id/nbt/p323502830
# A vision or dreame contayning the whole state of the Netherland warres.
# 1615
#
#
# http://data.bibliotheken.nl/id/nbt/p258233109
# The commvnion of saincts. A treatise of the fellowship that the faithful have with God.
# 1615
#
#
# http://data.bibliotheken.nl/id/nbt/p340284455
# A true relation of the treasons attempted against foure townes in the Low Countries.
# 1615
#
#
# http://data.bibliotheken.nl/id/nbt/p260659452
# A manvmission to a manvdvction, or Answer to a letter inferring publique communion in the parrish assemblis upon private with godly persons there.
# 1615
#
#
# http://data.bibliotheken.nl/id/nbt/p080575102
# A revelation of the Reuelation that is. The Revelation of St. John opened.
# 1615
#
#
# http://data.bibliotheken.nl/id/nbt/p260842125
# The first booke of the famous historye of Penardo and Laissa.
# 1615
#
#
# http://data.bibliotheken.nl/id/nbt/p267581092
# A garden of flovvers, wherein [...] is contained a [...] discription of al the flovvers contained in these fovre [...] bookes.
# 1615
#
#
# http://data.bibliotheken.nl/id/nbt/p25634986X
# The trying ovt of the trvth: begvnn and proseqvvted in certayn letters or passages.
# 1615
#
#
# http://data.bibliotheken.nl/id/nbt/p260379662
# The famovs historie of the renouned and valiant prince Robert surnamed the Brvce king of Scotland.
# 1615
#
#
# http://data.bibliotheken.nl/id/nbt/p258191481
# A letter first written and sent by Io. Forbes [...] for resolving this question
# 1616
#
#
# http://data.bibliotheken.nl/id/nbt/p338824316
# A collection of sundry matters.
# 1616
#
#
# http://data.bibliotheken.nl/id/nbt/p338822240
# A confession and protestation of the faith of certaine Christians in England.
# 1616
#
#
# http://data.bibliotheken.nl/id/nbt/p427501733
# Colloqvia et dictionariolvm septem lingvarvm, Belgicae, Tevtonicae, Anglicae, Gallicae, Latinae, Hispanicae et Italicae [...].
# 1616
#
#
# http://data.bibliotheken.nl/id/nbt/p058027424
# A treatise tending to cleare the doctrine of ivstification.
# 1616
#
#
# http://data.bibliotheken.nl/id/nbt/p115822755
# The revelation of S. Iohn illustrated with an analysis & scholions.
# 1616
#
#
# http://data.bibliotheken.nl/id/nbt/p323383785
# A fvll and plaine declaration of ecclesiastical discipline ovt of the word of God, and of the declining of the Church of England from the same.
# 1617
#
#
# http://data.bibliotheken.nl/id/nbt/p256141525
# A christian plea conteyning three treatises. The first, touching the anabaptists [...]. The second, touching such christians [...] commonly called remonstrants or arminiants. The third, touching the reformed churches.
# 1617
#
#
# http://data.bibliotheken.nl/id/nbt/p166073113
# Annotations upon the second book of Moses, called Exodvs.
# 1617
#
#
# http://data.bibliotheken.nl/id/nbt/p166071536
# Annotations upon the book of Psalmes.
# 1617
#
#
# http://data.bibliotheken.nl/id/nbt/p323383076
# An admonition to the parliament holden in the 13. yeare of the reigne of qveene Elizabeth
# 1617
#
#
# http://data.bibliotheken.nl/id/nbt/p323382185
# An abridgement of that booke which the ministers of Lincolne diocesse deliuered to his Maiestie vpon the first of December 1605. Being the first part of an apologie for themselves and their brethren that refvse the subscription and conformitie which is required
# 1617
#
#
# http://data.bibliotheken.nl/id/nbt/p115649360
# A plaine and familiar exposition of the tenne commandements.
# 1617
#
#
# http://data.bibliotheken.nl/id/nbt/p413923525
# A discovrse of the abuses novv in question in the chvrches of Christ.
# 1617
#
#
# http://data.bibliotheken.nl/id/nbt/p32338420X
# A trve, modest, and ivst defence of the petition for reformation, exhibited to the kings most excellent maiestie. Containing an answere to the confutation published under the names of some of the vniuersitie of Oxford
# 1618
#
#
# http://data.bibliotheken.nl/id/nbt/p323384544
# Certain reasons of a private christian against conformitie to kneeling in the very act of receiving the Lords Supper.
# 1618
#
#
# http://data.bibliotheken.nl/id/nbt/p323402283
# A frvitfvll sermon vpon the 3. 4. 5. 6. 7. and 8. verses of the 12. chapter of the Epistle of Paul to the Romanes
# 1618
#
#
# http://data.bibliotheken.nl/id/nbt/p323410731
# The peoples plea for the exercise of prophesie.
# 1618
#
#
# http://data.bibliotheken.nl/id/nbt/p166072451
# Annotations upon the third book of Moses, called Leviticvs.
# 1618
#
#
# http://data.bibliotheken.nl/id/nbt/p265591325
# An arrovv against the separation of the Brownists.
# 1618
#
#
# http://data.bibliotheken.nl/id/nbt/p323384749
# A little treatise vpon the first verse of the 122. psalme stirring up unto carefull desiring and dutifull labouring for the true church governement.
# 1618
#
#
# http://data.bibliotheken.nl/id/nbt/p059411384
# A confvtation of the rhemists translation, glosses and annotations on the Nevv Testament.
# 1618
#
#
# http://data.bibliotheken.nl/id/nbt/p323385605
# An ansvver to the ten covnter demands propovnded by T. Drakes.
# 1619
#
#
# http://data.bibliotheken.nl/id/nbt/p344105415
# The vnlawfvlnes of reading in prayer. Or, The answer of mr Richard Mavnsel preacher, vnto certain argvments, or reasons, drawne against the using [...] in, or with the Booke of Common Prayer [...] in the parish assemblies of England.
# 1619
#
#
# http://data.bibliotheken.nl/id/nbt/p24932735X
# The Messiah already come. Or, Profes of chistianitie [...] to convince the iewes,  of their [...] blindnesse  [...] for their long [...] expectation of their Messiah [...] yet for to come.
# 1619
#
#
# http://data.bibliotheken.nl/id/nbt/p85366210X
# The reasons which compelled the States of Bohemia to reiect the archiduke Ferdinand &c. & [...] to elect a new king.
# 1619
#
#
# http://data.bibliotheken.nl/id/nbt/p252067231
# A cleare demonstration that Ferdinand is by his owne demerits fallen from the kingdome of Bohemia.
# 1619
#
#
# http://data.bibliotheken.nl/id/nbt/p115691561
# Perth assembly.
# 1619
#
#
# http://data.bibliotheken.nl/id/nbt/p166072230
# Annotations upon the fourth book of Moses, called Numbers.
# 1619
#
#
# http://data.bibliotheken.nl/id/nbt/p252067037
# A short relation of the departure of [...] prince Frederick [...] of Bohemia
# 1619
#
#
# http://data.bibliotheken.nl/id/nbt/p16607196X
# Annotations upon the fifth book of Moses called Devteronomie.
# 1619
#
#
# http://data.bibliotheken.nl/id/nbt/p323385001
# The second part of a plain discovrse of an vnlettered christian, wherein by way of demonstration hee shevveth vvhat the reasons bee vvhich hee doth ground upon, in refusing conformity to kneeling in the act of receiving the Lords Supper.
# 1619
#
#
# http://data.bibliotheken.nl/id/nbt/p261812718
# Tvvo letters or embassies. The one sent by The States of Bohemia, to the elector of Saxony
# 1620
#
#
# http://data.bibliotheken.nl/id/nbt/p260118087
# A most true relation of the late proceedings in Bohemia, Germany, and Hungaria. Dated the 1. the 10. and 13. of iuly, this present yeere 1620.
# 1620
#
#
# http://data.bibliotheken.nl/id/nbt/p297499998
# Vox popvli. Or Newes from Spayne. [...]. Which may serue to forwarne both England and the Vnited Provinces how farre to trust to Spanish pretences.
# 1620
#
#
# http://data.bibliotheken.nl/id/nbt/p328055751
# A reply to a pretended christian plea for the anti-chistian[!] chvrch of Rome: published by mr. Francis Iohnson.
# 1620
#
#
# http://data.bibliotheken.nl/id/nbt/p260659290
# The late good svccesse and victory, which it pleased God to giue to some of the king of Bohemia's forces, vnder the conduct of the prince of Anhalt
# 1620
#
#
# http://data.bibliotheken.nl/id/nbt/p17084630X
# Vox popvli. Or Newes from Spayne. [...]. Which may serve to forewarn both England and the United Provinces how farre to trust to Spanish pretences.
# 1620
#
#
# http://data.bibliotheken.nl/id/nbt/p252088220
# The speach of the kirk of Scotland to her beloved children.
# 1620
#
#
# http://data.bibliotheken.nl/id/nbt/p258204869
# The crowne conivgall or, The spovse royall. A discovery of the true honor and happines of christian matrimony.
# 1620
#
#
# http://data.bibliotheken.nl/id/nbt/p328200441
# A declaration of the cavses, for the which, wee Frederick [...] king of Bohemia [...] haue accepted of the crowne of Bohemia
# 1620
#
#
# http://data.bibliotheken.nl/id/nbt/p831248181
# A declaration of the cavses, for the which, wee Frederick [...] king of Bohemia [...] haue accepted of the crowne of Bohemia
# 1620
#
#
# http://data.bibliotheken.nl/id/nbt/p328055964
# The faithfvll and vvise preventer or covnseller: or, Necessary considerations to be thought vpon by [...] prince Maurice.
# 1621
#
#
# http://data.bibliotheken.nl/id/nbt/p328056197
# A relation of some speciall points concerning the State of Holland. Or, The provident counsellours companion [...] shewing, why for the [...] vnited Prouinces warre is much better then peace
# 1621
#
#
# http://data.bibliotheken.nl/id/nbt/p252105109
# A notable and wonderfull sea-fight, betweene two [...] Spanish shipps, and a small [...] English shipp
# 1621
#
#
# http://data.bibliotheken.nl/id/nbt/p31616013X
# The diocesans tryall. Wherein all the sinnews of D. Dovvnams Defence are brought unto three heads, and orderly dissolved.
# 1621
#
#
# http://data.bibliotheken.nl/id/nbt/p166073652
# Annotations upon the first book of Moses, called Genesis.
# 1621
#
#
# http://data.bibliotheken.nl/id/nbt/p328200506
# Certaine letters declaring in part the passage of affaires in the Palatinate
# 1621
#
#
# http://data.bibliotheken.nl/id/nbt/p25226391X
# The first and second booke of discipline. Together with some acts of the generall assemblies
# 1621
#
#
# http://data.bibliotheken.nl/id/nbt/p252073207
# A briefe description of the reasons that make the declaration of the ban made against the king of Bohemia [...] of no value
# 1621
#
#
# http://data.bibliotheken.nl/id/nbt/p055707572
# Iacobs staffe. To beare vp, the faithfull. And to beate downe, the profane.
# 1621
#
#
# http://data.bibliotheken.nl/id/nbt/p326736093
# Abels offering. Or the earely, and most accepted sacrifice of a christian [...]. A sermon preached at Hamburg in november 1617.
# 1621
#
#
# http://data.bibliotheken.nl/id/nbt/p21281785X
# The Hollanders declaration of the affaires of the East Indies. Or A trve relation of that which passed in the ilands of Banda in [...] 1621 and before.
# 1622
#
#
# http://data.bibliotheken.nl/id/nbt/p079273424
# A proclamation made and proclaimed in Holland, &c. by the [...] generall States [...] prohibiting all iesuites [...] and other spirituall persons of the Romish religion, to come into the vnited Netherland Prouinces
# 1622
#
#
# http://data.bibliotheken.nl/id/nbt/p226851680
# The Belgicke pismire: stinging the slothfull sleeper, and avvaking the diligent.
# 1622
#
#
# http://data.bibliotheken.nl/id/nbt/p039931218
# The Belgicke pismire: stinging the slothfull sleeper, and avvaking the diligent.
# 1622
#
#
# http://data.bibliotheken.nl/id/nbt/p226781569
# The course of conformitie as it hath proceeded [...] should be refused.
# 1622
#
#
# http://data.bibliotheken.nl/id/nbt/p226198995
# A reply to dr. Mortons generall defence of three nocent ceremonies.
# 1622
#
#
# http://data.bibliotheken.nl/id/nbt/p207212449
# The best merchandise or, A cleare discovery of The evident difference, and admirable advantage, betweene our traffike with God, for the true treasure; and with men, for temporall commodity.
# 1622
#
#
# http://data.bibliotheken.nl/id/nbt/p230018769
# Taylors farevvell, to the tovvre-bottles
# 1622
#
#
# http://data.bibliotheken.nl/id/nbt/p423315307
# The Dvke de Mayennes ghost speaking to the princes, lords, and gentlemen of France.
# 1622
#
#
# http://data.bibliotheken.nl/id/nbt/p217580068
# Paraclesis contra Danielis Tileni Parænesin.
# 1622
#
#
# http://data.bibliotheken.nl/id/nbt/p03993134X
# A tongve-combat, lately happening betvvene tvvo English souldiers in the tilt-boat of Grauesend, the one going to serve the king of Spain, the other to serue the [...] Vnited Provinces.
# 1623
#
#
# http://data.bibliotheken.nl/id/nbt/p207212295
# The saints advantage or The welfare of the faithfvll, in the worst times. A sermon, preached at the Hage the 18. of May, 1623.
# 1623
#
#
# http://data.bibliotheken.nl/id/nbt/p172239664
# The spared hovres of a sovldier in his travels. Or The true marrowe of the French tongue [...].
# 1623
#
#
# http://data.bibliotheken.nl/id/nbt/p039931811
# The high-waies of God and the king [...]. Deliuered in tvvo sermons [...] anno 1620.
# 1623
#
#
# http://data.bibliotheken.nl/id/nbt/p039932079
# The proiector. Teaching a direct, svre, and ready vvay to restore the decayes of the church and state both in honour and revenue. Delivered in a sermon before the iudges in Norvvich [...] anno 1620.
# 1623
#
#
# http://data.bibliotheken.nl/id/nbt/p166071730
# Solomons Song of songs.
# 1623
#
#
# http://data.bibliotheken.nl/id/nbt/p832309230
# Votivæ Angliæ: or The desires and vvishes of England [...]. Wherein are unfolded [...] reasons [...] to perswade his majestie to drawe his royall sword, for the restoring of the Pallatynat, and Electorat.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p226781488
# Speculum belli sacri: or the lookingglasse of the holy war.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p226200345
# A dispvte vpon commvnicating at ovr confused communions.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p226200736
# An epistle of a christian brother exhorting an other to keepe himselfe vndefiled from the present corruptions brought in to the ministration of the Lords Supper.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p207224137
# The second part of Vox popvli, or Gondomar appearing in the likeness of Matchiauell in a Spanish parliament.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p207224366
# The second part of Vox popvli, or Gondomar appearing in the likenes of Matchiauell in a Spanish parliament.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p226200256
# An exhortation of the particular kirks of Christ in Scotland to their sister kirk in Edinburgh.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p252260627
# Vox popvli. Or Newes from Spayne [...]. Which may serve to forewarn both England and the Vnited Provinces how farre to trust to Spanish pretences.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p832114553
# The Belgick sovldier: dedicated to the parliament. Or, VVarre was a blessing.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p830965955
# The second part of Vox populi, or Gondomar appearing in the likenes of Matchiauell in a Spanish parliament.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p226720152
# An oration or speech appropriated vnto the [...] princes of christendom. Wherein the right [...] of the Netherlandish warre, against Phillip king of Spain is approved.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p217618073
# A defence of the doctrine propovnded by the Synode at Dort.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p205183182
# Aphorismes of state: or Certaine secret articles for the reedifying of the Romish chvrch agreed vpon [...] by the colledge of cardinalls in Rome.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p171382331
# Aphorismes of state: or Certaine secret articles for the reedifying of the Romish chvrch agreed vpon [...] by the colledge of cardinalls in Rome.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p039930718
# Vox regis.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p065655249
# Votivæ Angliæ: or The desires and vvishes of England [...]. Wherein are vnfolded [...] reasons [...] to perswade his majestie to drawe his royall sword, for the restoring of the Pallatynat, and Electorat.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p039927954
# Vox popvli
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p204840538
# Aphorismes of state: or Certaine secret articles for the reedi-fying of the Romish church, agreed vpon [...] by the colledge of cardinalls in Rome.
# 1624
#
#
# http://data.bibliotheken.nl/id/nbt/p226199274
# A shorte treatise against stage-playes.
# 1625
#
#
# http://data.bibliotheken.nl/id/nbt/p227228308
# The sea-mirrovr.
# 1625
#
#
# http://data.bibliotheken.nl/id/nbt/p226198499
# Sacræ heptades, or Seaven problems concerning antichrist.
# 1625
#
#
# http://data.bibliotheken.nl/id/nbt/p204346622
# A ivst and necessarie apologie of certain christians [...] commonly called Brownists or Barrowists.
# 1625
#
#
# http://data.bibliotheken.nl/id/nbt/p217618286
# Observations divine and morall. For the fvrthering of knowledg, and vertue.
# 1625
#
#
# http://data.bibliotheken.nl/id/nbt/p207228515
# Miles christianvs , or The campe royal set forth in briefe meditations on the words of the prophet Moses, Deut. 23, 9, 14 [...] preached in the armie at Dungen-leager.
# 1625
#
#
# http://data.bibliotheken.nl/id/nbt/p083715061
# The light of navigation.
# 1625
#
#
# http://data.bibliotheken.nl/id/nbt/p265543738
# The whole booke of psalmes.
# 1626
#
#
# http://data.bibliotheken.nl/id/nbt/p205183549
# A plaine and trve relation, of the going forth of a Holland fleete the eleuenth of nouember 1623, to the coast of Brasile.
# 1626
#
#
# http://data.bibliotheken.nl/id/nbt/p214145875
# A catechisme of christian religion
# 1626
#
#
# http://data.bibliotheken.nl/id/nbt/p841897913
# Sir VValter Ravvleighs ghost, or Englands forewarner.
# 1626
#
#
# http://data.bibliotheken.nl/id/nbt/p344105695
# A frvitfvll sermon.
# 1626
#
#
# http://data.bibliotheken.nl/id/nbt/p842035931
# Proteus ofte Minne-beelden verandert in sinne-beelden.
# 1627
#
#
# http://data.bibliotheken.nl/id/nbt/p831256176
# The prerogative of parliaments in England.
# 1628
#
#
# http://data.bibliotheken.nl/id/nbt/p226929906
# A briefe description of the notoriovs life of Iohn Lambe, otherwise called doctor Lambe
# 1628
#
#
# http://data.bibliotheken.nl/id/nbt/p226756289
# The commvnion of saincts. A treatise of the fellowship, that the faithfull haue with God [...] in this present life.
# 1628
#
#
# http://data.bibliotheken.nl/id/nbt/p212869876
# The prerogative of parliaments in England.
# 1628
#
#
# http://data.bibliotheken.nl/id/nbt/p324182775
# The commvnion of saincts. A treatise of the fellowship, that the faithfull haue with God [...] in this present life.
# 1628
#
#
# http://data.bibliotheken.nl/id/nbt/p217642292
# The spy discovering the danger of arminian heresie and Spanish treckerie.
# 1628
#
#
# http://data.bibliotheken.nl/id/nbt/p227026098
# An appeal to the Parliament; or Sions plea against the prelacie.
# 1629
#
#
# http://data.bibliotheken.nl/id/nbt/p227025938
# An appeal to the Parliament; or Sions plea against the prelacie.
# 1629
#
#
# http://data.bibliotheken.nl/id/nbt/p207367973
# The book of prayses, called the Psalmes.
# 1629
#
#
# http://data.bibliotheken.nl/id/nbt/p205181317
# The campe royal, set forth in briefe meditations on the words of the prophet Moses, Deut. 23. 9. 14 [...] preached in the army at the leager.
# 1629
#
#
# http://data.bibliotheken.nl/id/nbt/p226799409
# Bausme de Galaad, pour la guérison d'un coeur navrè: offert a sa maiesté de Boheme: en quatre langues.
# 1629
#
#
# http://data.bibliotheken.nl/id/nbt/p226799573
# Dakrva basilika. That is, The princly teares of Elisabetha, queene of Bohemia: ouer the death, of her eldest sonne, Fridericvs Henricvs.
# 1629
#
#
# http://data.bibliotheken.nl/id/nbt/p851159036
# Evropæ specvlvm. Or, A view or svrvey of the state of religion in the westerne parts of the world.
# 1629
#
#
# http://data.bibliotheken.nl/id/nbt/p083943234
# The reasons for vvhich the most illustrious and most potent prince [...] Gustavus Adolphus [...] vvas at length forced to march vvith an army into Germany
# 1630
#
#
# http://data.bibliotheken.nl/id/nbt/p323411568
# Colloqvia et dictionariolvm octo lingvarvm, Latinæ, Gallicæ, Belgicæ, Tevtonicæ, Hispanicæ, Italicæ, Anglicæ, et Portvgallicæ [...].
# 1630
#
#
# http://data.bibliotheken.nl/id/nbt/p328200573
# The originall of popish idolatrie, or The birth of heresies.
# 1630
#
#
# http://data.bibliotheken.nl/id/nbt/p840761600
# A historicall relation of the famous siege of the citie called The Bvsse.
# 1630
#
#
# http://data.bibliotheken.nl/id/nbt/p226751619
# A trve relation of the vanquishing of the towne Olinda, cituated in the capitania of Phernambvco. Through [...] Henry C. Lonck, generall by sea and land
# 1630
#
#
# http://data.bibliotheken.nl/id/nbt/p208181091
# A historicall relation of the famous siege of the Busse, and the surprising of Wesell.
# 1630
#
#
# http://data.bibliotheken.nl/id/nbt/p840833342
# Digitvs Dei. Or Good newes from Holland. Sent to the wor.ll John Treffry. and John Trefvsis.
# 1631
#
#
# http://data.bibliotheken.nl/id/nbt/p205151671
# A christian reprofe against contention. Wherein is declared [...] a just defence of the church, against such slanderes [...] which Sabine Staresmore hath layd vpon vs in his two bookes.
# 1631
#
#
# http://data.bibliotheken.nl/id/nbt/p217622003
# A trve table of all svch fees as are due to the bishop of London, and all his depending officers.
# 1631
#
#
# http://data.bibliotheken.nl/id/nbt/p202456129
# The firme aliance & agreement made betvveene his matie the king of Svvethland [...] and [...] the duke of Statin and Pomerland.
# 1631
#
#
# http://data.bibliotheken.nl/id/nbt/p157102912
# Lawes and ordinances touching military discipline. Set downe and established the 13. of august. 1590.
# 1631
#
#
# http://data.bibliotheken.nl/id/nbt/p21763981X
# The booke of psalmes.
# 1632
#
#
# http://data.bibliotheken.nl/id/nbt/p850882745
# The psalmes of David.
# 1632
#
#
# http://data.bibliotheken.nl/id/nbt/p202268543
# A sermon discvrsing the true meaning of [...] the 1. Epistle of Timothy, the 2. chapt. vers. the 4.
# 1632
#
#
# http://data.bibliotheken.nl/id/nbt/p39320491X
# The King of Svvethens progresse into Germanie [...] vvith a short discription of the great battle of Lypsich [...] and a list to vvhat a nvmber the kings armies are encreased, since his arriuall in High Dutchland
# 1632
#
#
# http://data.bibliotheken.nl/id/nbt/p405062656
# An alarme to all christian princes and states of the religion. Written immediatly vpon the first newes of the death of the king of Sweden
# 1632
#
#
# http://data.bibliotheken.nl/id/nbt/p832695076
# A iovrnall, of the taking in of Venlo, Roermont, Strale [...] vnder the able, and wise conduct of his excie: the prince of Orange, anno 1632.
# 1633
#
#
# http://data.bibliotheken.nl/id/nbt/p335881874
# The Bible, that is, The holy Scriptures conteined in the Olde and Newe Testament
# 1633
#
#
# http://data.bibliotheken.nl/id/nbt/p203732022
# The tragicall life and death of Mvley Abdala Melek the late king of Barbarie.
# 1633
#
#
# http://data.bibliotheken.nl/id/nbt/p267297777
# Het heylighdom der benaude ziele.
# 1633
#
#
# http://data.bibliotheken.nl/id/nbt/p335875777
# The Bible, that is, The holy Scriptures conteined in the Olde and Newe Testament
# 1633
#
#
# http://data.bibliotheken.nl/id/nbt/p138917590
# A fresh svit against human ceremonies in God's vvorship.
# 1633
#
#
# http://data.bibliotheken.nl/id/nbt/p217261973
# A treatise of the lawfvlnes of hearing of the ministers in the church of England.
# 1634
#
#
# http://data.bibliotheken.nl/id/nbt/p226721191
# A necessitie of separation from the church of England, prooved by the nonconformists principles.
# 1634
#
#
# http://data.bibliotheken.nl/id/nbt/p353577774
# The Holy Bible containing the Old Testament and the New
# 1634
#
#
# http://data.bibliotheken.nl/id/nbt/p266227996
# Fonteyne des levens, dat is: De historie van de Samaritaensche vrouwe. Verklaert ende toe-geeygent in 76. goddelijcke meditatien.
# 1634
#
#
# http://data.bibliotheken.nl/id/nbt/p217262422
# The opinion, judgement, and determination of two [...] divines of the church of England, concerning bowing at the name [...] of Jesus.
# 1634
#
#
# http://data.bibliotheken.nl/id/nbt/p215998316
# The trve pictvre and relation of prince Henry his noble and vertuous disposition.
# 1634
#
#
# http://data.bibliotheken.nl/id/nbt/p217267467
# The importvnate begger for things necessary [...]. Or a treatise, wherein is shewed the lawfullnesse of praying absolutely for necessary temporall things.
# 1635
#
#
# http://data.bibliotheken.nl/id/nbt/p172115892
# The chvrches plea for her right. Or A reply to an answer, made of mr. Iohn Paget, against William Best and others.
# 1635
#
#
# http://data.bibliotheken.nl/id/nbt/p214227715
# A brief and short treatise, called the christians pilgrimage to his fatherland.
# 1635
#
#
# http://data.bibliotheken.nl/id/nbt/p217258816
# Fovr sermons which doe manifest the true sence of the 1. epistle to Timothie 6. chapter 13.14.15. & 16. verses.
# 1635
#
#
# http://data.bibliotheken.nl/id/nbt/p334152860
# A brief answer to a late Treatise of the Sabbath day.
# 1635
#
#
# http://data.bibliotheken.nl/id/nbt/p213689243
# Isaacks pilgrimage. A brief [...] treatise, of the strife that Isaack had with his heard-men.
# 1635
#
#
# http://data.bibliotheken.nl/id/nbt/p853141363
# The sea-mirrovr.
# 1635
#
#
# http://data.bibliotheken.nl/id/nbt/p344461785
# An answer to the unjust complaints of William Best [...]. Also an answer to mr. Iohn Davenport.
# 1635
#
#
# http://data.bibliotheken.nl/id/nbt/p326741283
# The chvrches plea for her right. Or A reply to an answer, made of mr. Iohn Paget, against William Best and others.
# 1635
#
#
# http://data.bibliotheken.nl/id/nbt/p217264352
# A complete concordance to the Bible of the last translation.
# 1635
#
#
# http://data.bibliotheken.nl/id/nbt/p353578363
# The whole booke of psalmes.
# 1635
#
#
# http://data.bibliotheken.nl/id/nbt/p217643086
# Concerning the holy eucharist and the popish breaden-god to the men of Rome.
# 1636
#
#
# http://data.bibliotheken.nl/id/nbt/p217258913
# An apology of an appeale. Also an epistle to the true-hearted nobility.
# 1636
#
#
# http://data.bibliotheken.nl/id/nbt/p217261752
# ...
# Notes upon the twelve books of Paradise lost, Collected from the Spectator.
# 173X
#
#
# http://data.bibliotheken.nl/id/nbt/p308097459
# A particular account of the present siege of Mastricht with the sundry remarkable circumstances thereto relating.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p308162242
# Supplementum catalogi librorum, Latinorum incompactorum qui in officina Bemanniana inveniuntur
# 176X
#
#
# http://data.bibliotheken.nl/id/nbt/p30812359X
# A letter to a dissenter, upon occasion of his majesty's late gracious Declaration of indulgence.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p308451260
# A dissertation on the Eleusinian and Bacchic mysteries.
# 179X
#
#
# http://data.bibliotheken.nl/id/nbt/p309558980
# Twelve divertimentis or duets for two violins for the use of beginners [...] opera quarta.
# 178X
#
#
# http://data.bibliotheken.nl/id/nbt/p31075772X
# Nieuwe ordonnantie en instructie van de Staaten van Holland en Westvriesland, beroerende het stuk van de pilotage [...]. Waar na alle aangenoomen lootsluiden op Vlieland en ter Schelling, haar sullen hebben te reguleeren
# 170X
#
#
# http://data.bibliotheken.nl/id/nbt/p311669018
# Second catalogue des livres
# 180X
#
#
# http://data.bibliotheken.nl/id/nbt/p31182532X
# Groote vissery.
# 17XX
#
#
# http://data.bibliotheken.nl/id/nbt/p312647522
# An apology for the church of Eugland[!], with relation to the spirit of persecution: for which she is accused.
# 168X
#
#
# http://data.bibliotheken.nl/id/nbt/p313972842
# Le bijoutier philosophe. Comedie.
# 17XX
#
#
# http://data.bibliotheken.nl/id/nbt/p32136094X
# The examinations of Henry Barrowe Iohn Grenewood and Iohn Penrie, before the high commissioners, and Lordes of the Counsel. Penned by the prisoners themselues before their deathes.
# 159X
#
#
# http://data.bibliotheken.nl/id/nbt/p320488314
# Nader reglement over het loon van een tweede loots
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p321458532
# Generall sailing-orders according to whch masters as have a mind to saile are to ruled by
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p324246080
# A declaration of the witnes of God, manifested in the inward parts.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p323838995
# The booke of psalmes.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p325765472
# The Holy Bible, containing the Old Testament and the New
# 166X
#
#
# http://data.bibliotheken.nl/id/nbt/p32698609X
# A new cyropædia, or The travels of Cyrus.
# 17XX
#
#
# http://data.bibliotheken.nl/id/nbt/p326970738
# Six papers.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p41598212X
# A catalogue of English books [...] sold by Thomas Johnson bookseller in Rotterdam
# 173X
#
#
# http://data.bibliotheken.nl/id/nbt/p419366253
# La nouvelle cyropedie; ou Les voyages de Cyrus.
# 172X
#
#
# http://data.bibliotheken.nl/id/nbt/p330631349
# The Bible, that is, the Holy Scriptures conteined in the Olde and Newe Testament
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p330631608
# The booke of psalmes.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p330750208
# Explanation, of the famous and renowned glas-work. Or printed windows, in the [...] church at Gouda
# 17XX
#
#
# http://data.bibliotheken.nl/id/nbt/p330610465
# A trve description ovt of the word of God, of the visible church.
# 160X
#
#
# http://data.bibliotheken.nl/id/nbt/p333052544
# Three letters concerning the present state of Italy, written in the year 1687.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p335998666
# The Bible, that is, The Holy Scriptures conteined in the Olde and Newe Testament
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p336270798
# The booke of psalmes.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p335998658
# The booke of psalmes.
# 163X
#
#
# http://data.bibliotheken.nl/id/nbt/p336270542
# The booke of psalmes.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p336270917
# The booke of psalmes.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p335998682
# The booke of psalmes.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p315787600
# Explanation of the famous and renowned glas-work, or painted windows, in the [...] church at Gouda
# 17XX
#
#
# http://data.bibliotheken.nl/id/nbt/p316000299
# (Title B1v:) Boeck [...] om te leeren lesen, schrijven ende spreken Vlaems, Engel ch[!], Hoochduytsch, Latijn, Fransoys, Spaensch, Italiaensch, en̄ Portugis
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p316074071
# Explanation of the famous and renowned glas-work. or painted windows, in the [...] church at Gouda
# 17XX
#
#
# http://data.bibliotheken.nl/id/nbt/p31718539X
# Voyage sentimental [...] en anglais et en français.
# 179X
#
#
# http://data.bibliotheken.nl/id/nbt/p832448206
# Schat oft voorbeelt ende verthooninge van verscheyden geschriften ten dienste vande liefhebbers der hooch-loflijcker konste der penne.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p832704466
# Newes from Pernassvs. The politicall touchstone, taken from Mount Pernassus: whereon the governments of the greatest monarchies [...] are touched.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p423315404
# Explanation, of the famous and renowned glas-work. Or painted windows, in the [...] church at Gouda
# 17XX
#
#
# http://data.bibliotheken.nl/id/nbt/p430971516
# A brief treatise vpon the first table of the lavve, orderly disposing the principles of religion.
# 158X
#
#
# http://data.bibliotheken.nl/id/nbt/p252259211
# Vox popvli or Newes from Spayne [...]. Which may serve to forwarn both England and the Vnited provinces how farre to trust to Spanish pretences.
# 162X
#
#
# http://data.bibliotheken.nl/id/nbt/p260658561
# Obiections: answered by way of dialogue, wherein is proved [...] that no man ought to be persecuted for his religion.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p264128737
# The Bible that is, The Holy Scriptures conteined in the Olde and Newe Testament
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p26502059X
# A censure of the late translation for our churches.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p264223004
# The sacred doctrine of divinitie, gathered ovt of the worde of God.
# 15XX
#
#
# http://data.bibliotheken.nl/id/nbt/p268632251
# Maniement d'armes d'arqvebuses, mousqvetz, et picques [...].
# 161X
#
#
# http://data.bibliotheken.nl/id/nbt/p270133739
# Sinn'- en minne beelden.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p273828002
# A dialogue between two jesuits, father Antony and father Ignativs, at Amsterdam, the one coming from England, and the other going thither
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p290682010
# An appeal to the parliament, or Sions against the prelacy.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p292062362
# Observations vpon the Prince of Orange and the States of Holland
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p292823746
# Memorie voor Hope en Compagnie, kooplieden te Amsterdam. Dienende tot eene volledige justificatie van het verzoek door denzelven aan HH. HH. MM. wegens de laading van het schip, the Illustrious president, gedaan; en eene compleete refutatie der contradictie door bewindhebberen van de O. I. Comp. daar tegen gemoveerd
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p29629263X
# The New Testament of our Lord Iesvs Christ.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p37141492X
# The Bible, that is, The Holy Scriptures conteined in the Olde and Newe Testament
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p297477420
# Epistolae HN. The principall epistles of HN, which he hath set-foorth through the holy spirit of loue.
# 160X
#
#
# http://data.bibliotheken.nl/id/nbt/p298049325
# A petition to the king to hasten allowance for Ebrew institvtion of Ebrevves.
# 161X
#
#
# http://data.bibliotheken.nl/id/nbt/p29806183X
# A svpplication to the kinges maiestie, concerning pitie toward the iewes of ovr Constantines towne.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p29821430X
# Marmora et adfines aliquos lapides coloribus suis.
# 17XX
#
#
# http://data.bibliotheken.nl/id/nbt/p300354282
# A catechisme of christian religion
# 17XX
#
#
# http://data.bibliotheken.nl/id/nbt/p301149410
# A defence of the people of England [...] in answer to Salmasius's Defence of the king. By John Milton
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p375831835
# Papieren door zyn hoogheid ter vergadering van hun ed. groot mog. op den 20 october 1780 overgegeeven
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p382609484
# To his highnesse the Lord Protector of the Common-Wealth of England, Scotland, and Ireland. The humble addresses of Menasseh Ben Israel [...] on behalfe of the jewish nation
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p385916531
# Eximiæ peritiæ alphabetvm, complura graphica exemplaria continens, totidemque diuersarum literarvm characteres, septem diversis lingvis expressos.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p383422019
# Missive van commissarissen van 'slands postereyen, met een brief van den secretaris van het generaal postofficie te Londen over de schuld wegens de vyf laatste quartaals reekeningen, en de toegebragte schaaden door het opbrengen der pacquetboot de Dolphyn [...]. 20 maart 1784
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p386034389
# [Woordenlijst in het Engels, Nederlands en Frans]
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p395067316
# The lively oracles given to us.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p397607733
# Catalogus van oranje-citroen-limoen en verscheide Americaansche en andere uitheemsche boomen en heesters [...] die [...] te bekomen zyn by Jacobus Gans, bloemist te Haarlem en Hillegom
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p397915578
# Een declaratie defensive vanden col: liev: Ioan Lilbvrne, tegen het onrecht veerdigh banissement by het gedissipeerde Engelsch parlament gevvesen, vvt de stadt Brugghe in Vlaendren den 14 mey 1653.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p39852467X
# Nieuwe vermeerde[!] en verbeterde catalogus van in- en uitlandsche boomen, heesters en plantagie-gewassen [...] te bekomen by Jacobus Gans, bloemist [...] te Hillegom by Haarlem
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p400977389
# Groote en kleene voorbeelden van alderhande door-eengevlogte naam letteren.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p400806703
# Nieuwe ordonnantie en instructie, van de Staaten van Holland en Westvriesland, beroerende het stuk van de pilotage [...], waar na alle aengenoomen loots-luiden op Vlieland en ter Schelling, haar sullen hebben te reguleeren
# 170X
#
#
# http://data.bibliotheken.nl/id/nbt/p404318169
# XII Sonate à tre due violini e violoncello col basso per l'organo [...] opera prima.
# 170X
#
#
# http://data.bibliotheken.nl/id/nbt/p851039286
# The pourtraicture of his sacred majestie.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p851156274
# Princely virtuous academicall discours, concerning military architecture, or fortifications.
# 166X
#
#
# http://data.bibliotheken.nl/id/nbt/p853285306
# A placarde or statute concerning the musters where by to prevent all frauwde used by the not-keeping of the companies full
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p861438981
# The king of Great-Brittaines declaration, to the [...] States Generall of the Vnited Provinces. Exhibited [...] the 9 iulie, 1643
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p862208874
# Een verclaringe vande officieren ende compagnie van het zee-volck, oft matrosen op sijne majesteyts schepen.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p863182127
# Discours noopende den tegenwoordigen tijdt
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p863833330
# Lettre escrite de Londres. Le 22 decembre 1688
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p306974665
# Voyage sentimental [...] en anglais et en français.
# 179X
#
#
# http://data.bibliotheken.nl/id/nbt/p30734228X
# The lord general Cromwel's speech delivered in the council-chamber, upon the 4 of july, 1653
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p308007778
# Lettre du chevalier *** a mylord *** Sur le danger que court la liberte angloise, & sur l'unique moïen de l'en garentir.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p842399399
# Afbeeldingen der voornaamste historien, soo van het Oude als Nieuwe Testament.
# 17XX
#
#
# http://data.bibliotheken.nl/id/nbt/p036013064
# Introdvctio. An introduction to the holy vnderstanding of the glasse of righteousnes.
# 160X
#
#
# http://data.bibliotheken.nl/id/nbt/p036508853
# Nader reglement over het loon van een tweede loots
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p039931137
# Digitvs Dei.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p039928438
# Vox Dei.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p039931595
# Symmachia: or, A trve-loves knot. Tyed, betvvixt Great Britaine and the Vnited Prouinces.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p055779239
# The practice of pietie: directing a christian how to walke that he may please God.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p05560269X
# Les abus du mariage [...].
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p056796250
# Bybel printen, vertoonende de voornaemste historien der Heylige Schrifture.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p080679625
# Exemplær-boec inhoudende alderhande gheschriften.
# 163X
#
#
# http://data.bibliotheken.nl/id/nbt/p085521337
# La dissection du corps humain, ou Le petit monde [...].
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p085523305
# Le miroir des plus belles covrtisannes de ce temps.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p086097059
# The practice of pietie: directing a christian how to walke that he may please God.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p096442514
# A nomenclator, English and Dutch [...].
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p101339747
# Reflections on Mr. Varillas's History of the revolutions that have happened in Europe in matters of religion.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p341470686
# Figures de [la Bible].
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p344100693
# A briefe discourse against the outvvarde apparell and ministring garmentes of the popishe church.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p344386147
# A brief treatise vpon the first table of the lavve, orderly disposing the principles of religion, whereby we may examine our selues.
# 158X
#
#
# http://data.bibliotheken.nl/id/nbt/p35625710X
# Poëtica stromata or A collection of sundry peices in poetry.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p357534425
# The confession of faith, and the larger & shorter catechism, first agreed upon by the assembly of divines at Westminster
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p369189035
# The practice of pietie: directing a christian how to walke that he may please God.
# 163X
#
#
# http://data.bibliotheken.nl/id/nbt/p369223020
# The practice of pietie: directing a christian how to walke that he may please God.
# 163X
#
#
# http://data.bibliotheken.nl/id/nbt/p369223799
# The practice of pietie: directing a christian how to walke that he may please God.
# 16XX
#
#
# http://data.bibliotheken.nl/id/nbt/p369223128
# The practice of pietie: directing a christian how to walke that he may please God.
# 163X
#
#
# http://data.bibliotheken.nl/id/nbt/p370590074
# Pictures of the Old and New Testaments, showing the most nottable[!] historys, in 150 copper platis[!] [...].
# 17XX
#
#
# http://data.bibliotheken.nl/id/nbt/p427507421
# [Colloqvia et dictionariolvm septem lingvarvm, Belgicæ, Anglicæ, Tevtonicæ, Latinae, Italicae, Hispanicae, Gallicae [...].]
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p424582597
# Catalogus van oranje-citroen-limoen en verscheide Americaansche en andere uitheemsche boomen en heesters [...] die [...] te bekomen zyn by Iacobus Gans. Bloemist te Haarlem.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p424582643
# Nieuwe vermeerde[!] en verbeterde catalogus van in- en uitlandsche boomen, heesters en plantagie-gewassen [...] te bekomen by Jacobus Munts, bloemist [...] in 's-Gravenhage
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p428525687
# Echtgezangen, voor den huwelyke van [...] Gerard Schepers [..] en [...] Jakoba Prins
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p433031301
# Εἰκὼν ἄκλαστος The image vnbroaken. A perspective [...] published in a libell entitled Εἰκονοκλάστης against Εἰκὼν Βασιλική or the pourtraicture of his sacred majestie in his solitudes and suffererings.
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p427437199
# [Engelse vertaling van Formulier van bidden voor de hooge ende subalterne overheyt, inde Nederduytsche kercken van Hollandt ende West-Vrieslandt]
# nan
#
#
# http://data.bibliotheken.nl/id/nbt/p427677106
# XXVII. lectvres or readinges, vpon part of the Epistle written to the Hebrues.
# 159X
#
#
# 1299

# %% [markdown]
# ## Subjects

# %%
subjects = []

for book in json_data:
    subjects.append(book['subjects'][0]['group'])
        
subjects_freq = Counter(subjects)

total = sum(subjects_freq.values())

for subject,count in subjects_freq.most_common():
    print(f"{subject} {count} {(count/total)*100}")

# %%
## Grammars and dictionaries

# %%
publishers = Counter()
count = 0

for book in json_data:
    if book['subjects'][0]['group'] == 'Language and literature':
        count += 1
        print(f"{book['ppn']}\n{book['title']}\n{book['year']}")
        publ_name = ''
        for publ in book['publishers']:
            print(publ['name'])
            publ_name += publ['name'] + '; '
        publishers.update([publ_name])
        for subject in book['subjects']:
            print(subject['label'])
        print('\n\n')
        
print(count)
        
for p,i in publishers.most_common():
    print(f"{p},{i}")

# %%
publishers = Counter()
count = 0

for book in json_data:
    if re.search( r'\d{4}', str(book['year']) ) and int(book['year']) > 1700:
        if book['subjects'][0]['group'] == 'Language and literature' and not re.search(r'(dict)|(gramm)|(taal)|(language)',book['title'],re.IGNORECASE):
            count += 1
            print(f"{book['ppn']}\n{book['title']}\n{book['year']}")
            publ_name = ''
            for publ in book['publishers']:
                print(publ['name'])
                publ_name += publ['name'] + '; '
            publishers.update([publ_name])
            for subject in book['subjects']:
                print(subject['label'])
            print('\n\n')
        
print(count)
        
for p,i in publishers.most_common():
    print(f"{p},{i}")
# Out:
# http://data.bibliotheken.nl/id/nbt/p268938709
# Love for love: a comedy.
# 1710
# Johnson, Thomas
# s.n.
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p402314840
# The rehearsal; a comedy.
# 1710
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p402315154
# The chances, a comedy.
# 1710
# Johnson, Thomas
# s.n.
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p268937818
# The old batchelour. A comedy.
# 1710
# Johnson, Thomas
# s.n.
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p412692457
# Hamlet, prince of Denmark. A tragedy.
# 1710
# Johnson, Thomas
# s.n.
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p326673261
# She wou'd if she cou'd. A comedy.
# 1710
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p268937982
# The mourning bride. A tragedy.
# 1711
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p412692538
# The tragedy of Macbeth.
# 1711
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p413017788
# The jew of Venice. A comedy.
# 1711
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p402314948
# The man of mode, or, Sr. Fopling Flutter. A comedy.
# 1711
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p342167804
# The orphan: or, The unhappy marriage. A tragedy.
# 1711
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p268939039
# The way of the world. A comedy.
# 1711
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p314090401
# Phædra and Hippolitus. A tragedy.
# 1711
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p268938970
# The double-dealer. A comedy.
# 1711
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p333031369
# Abra-mule: or, Love and empire. A tragedy.
# 1711
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p197746675
# Oroonoko: a tragedy.
# 1712
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p333030990
# Venice preserv'd; or, A plot discover'd. A tragedy.
# 1712
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216917727
# The distrest mother. A tragedy.
# 1712
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p333031202
# The adventures of five hours: a tragi-comedy.
# 1712
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p416807887
# The funeral, and The tender husband. Comedies.
# 1712
# Lloyd, Owen
# Scheurleer, Hendrik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p342164961
# A collection of the best English plays.
# 1712
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p217052924
# Volpone: or, The fox. A comedy.
# 1714
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p298855798
# An essay on criticism.
# 1716
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p29885791X
# The rape of the lock. An heroi-comical poem.
# 1716
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216923441
# The relapse; or, Virtue in danger [...] a comedy.
# 1717
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216909171
# The tragedy of the lady Jane Gray.
# 1718
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p298853817
# The works.
# 1718
# s.n.
# Lintot, Bernard
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p31724941X
# Nouvelle methode, pour aprendre facilement les langues françoise et angloise.
# 1718
# Duren, Johannes van (I)
# French language and literature
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216926270
# The non-juror. A comedy.
# 1718
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216897467
# Busiris, king of Egypt. A tragedy.
# 1719
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216907845
# Theodosius: or, The force of love. A tragedy.
# 1719
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216907381
# Sophonisba: or, Hannibal's overthrow. A tragedy.
# 1719
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p304663816
# Amvsements seriovs and comical [...]
# 1719
# Vaillant, Isaac
# French language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216921538
# Chit-chat. A comedy.
# 1719
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216897130
# The siege of Damascus. A tragedy.
# 1720
# Johnson, Thomas
# s.n.
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p214143023
# Amvsements seriovs and comical [...]
# 1720
# Vaillant, Isaac
# French language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p217035647
# The old batchelour, a comedy.
# 1720
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p217044743
# All for love: or, The world well lost. A tragedy.
# 1720
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p21704445X
# The Spanish fryar, or, The double discovery: a tragi-comedy.
# 1720
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p20202556X
# Poems on several occasions.
# 1720
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p21703506X
# Love for love: a comedy.
# 1720
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216568498
# Hamlet, prince of Denmark. A tragedy.
# 1720
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p341012882
# Miscellaneous works, comical & diverting.
# 1720
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216919339
# The recruiting officer, a comedy.
# 1720
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p21691910X
# The beaux strategem. A comedy.
# 1720
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p217043178
# The Indian emperor: or, The conquest of Mexico by the Spaniards.
# 1721
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216923670
# The provok'd wife
# 1721
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p217042848
# The state of innocence, and fall of man: an opera.
# 1721
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216926785
# The careless husband: a comedy.
# 1721
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p217055397
# Amphitryon: or The two Sosias. A comedy.
# 1721
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216920280
# The funeral: or, Grief a-la-mode. A comedy.
# 1721
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p217056164
# K. Henry IV. with the humours of sir John Falstaff. A tragi-comedy.
# 1721
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p217045049
# Aurenge-Zebe, or, The great-mogul. A tragedy.
# 1721
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p305386328
# The works.
# 1722
# Johnson, Thomas
# Latin language and literature
# History (antiquity)
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216920043
# The conscious lovers. A comedy.
# 1723
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p317893890
# The distrest mother. A tragedy.
# 1726
# Johnson, Thomas
# s.n.
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p318126494
# Cato, a tragedy.
# 1728
# Tonson, Jacob
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p412693992
# The lawyer's fortune: or, Love in a hollow tree. A comedy.
# 1728
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216894565
# Cato, a tragedy.
# 1730
# s.n.
# Johnson, Thomas
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p305620142
# Paradise lost, a poem, in twelve books.
# 1730
# Johnson, Thomas
# Company, the
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p21690658X
# The tragedy of Sophonisba.
# 1730
# s.n.
# Company, the
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p305619004
# The poetical works.
# 1731
# Johnson, Thomas
# s.n.
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p216905680
# The London merchant: with the tragical history of George Barnwell.
# 1731
# s.n.
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p189895284
# Metamorphoses.
# 1732
# Wetstein, Rudolf
# Smith, William
# Wetstein, Jacobus
# Latin language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p317287826
# The temple of the muses; or, The principal histories of fabulous antiquity, represented in sixty sculptures.
# 1733
# Chatelain, Zacharias (II)
# French language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p315906499
# Le temple des muses, orné de LX. tableaux où sont représentés les evenemens [...] de l'antiquité fabuleuse.
# 1733
# Chatelain, Zacharias (II)
# French language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p328666084
# A tale of a tub.
# 1734
# s.n.
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p236625519
# The English, Dutch, French, and Latin vocabulary [...]
# 1735
# Néaulme, Etienne
# Dutch language and literature
# French language and literature
# Latin language and literature
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p338764127
# The black-bird: a poem.
# 1741
# s.n.
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p298567393
# Short and clear instruction in the spelling and pronouncing the English tongue [...].
# 1747
# Douci Pietersz, Adriaan
# Pelt, Hendrik van
# Dutch language and literature
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p215118332
# A select collection of the best modern English plays.
# 1750
# Scheurleer Florisz, Hendrik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p215118189
# A select collection of the best modern English plays.
# 1750
# Scheurleer Florisz, Hendrik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p215118111
# A select collection of the best modern English plays.
# 1750
# Scheurleer Florisz, Hendrik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p215117921
# A select collection of the best modern English plays.
# 1750
# Scheurleer Florisz, Hendrik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p215117808
# A select collection of the best modern English plays.
# 1750
# Scheurleer Florisz, Hendrik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p21511728X
# A select collection of the best modern English plays.
# 1750
# Scheurleer Florisz, Hendrik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p215117204
# A select collection of the best modern English plays.
# 1750
# Scheurleer Florisz, Hendrik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p215116135
# A select collection of the best modern English plays.
# 1750
# Scheurleer Florisz, Hendrik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p215115953
# A select collection of the best modern English plays.
# 1750
# Scheurleer Florisz, Hendrik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p215118251
# A select collection of the best modern English plays.
# 1750
# Scheurleer Florisz, Hendrik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p191502650
# Den volkomene Engelsche spraakkonst, voor heeren en juffrouwen [...].
# 1752
# Knyff, Abraham de
# Dutch language and literature
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p220359342
# Volkome Engelsche spraakkonst [...].
# 1758
# Bosch, Jacobus
# Beman, Jan Daniel
# Kentlink, Hermanus
# Dutch language and literature
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p301918937
# Essai sur l'homme, poëme philosophique.
# 1762
# Chatelain, Henry Jedis
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p432617396
# Tales of passed times by mother goose.
# 1764
# Berg, S. van den
# French language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p432617426
# Tales of passed times by mother goose.
# 1764
# Melvil, J.
# French language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p328604895
# The best tragedie's and comedie's.
# 1765
# s.n.
# Company, the
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p153794542
# Essai de traduction litterale et énergique.
# 1771
# Enschedé, Johannes (I)
# Linguistics (general)
#
#
#
# http://data.bibliotheken.nl/id/nbt/p201969653
# Élémens de la langue angloise, ou Méthode pratique pour apprendre facilement cette langue.
# 1774
# s.n.
# Gosse, Pierre Frederik
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p291327133
# Proeve van overzetting uit het Engelsch.
# 1776
# Clement, Simon
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p305088939
# A clear, natural, and easy method of instruction in the spelling, and pronunciation of the English tongue.
# 1778
# Leeuw, Jan de
# Dekkers Mz, Johannes
# Dutch language and literature
# Education
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p317811096
# Uitvoerige Engelsche spraak-konst; in't Néder-duitsch ontvouwd.
# 1780
# Holtrop, Willem
# Blussé, Abraham
# Blussé, Pieter
# Dutch language and literature
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p301864314
# Volkoomen Engelsche spraakkunst [...].
# 1786
# Hendriksen, Jan
# Dutch language and literature
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p14772029X
# A new Ènglish and Dutch dìctionary [...].
# 1789
# Holtrop, Willem
# Eysden, Nicolaas van
# Blussé, Pieter
# Blussé, Abraham
# Dutch language and literature
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p148202152
# Uitvoerige Engelsche spraak-konst, in't Nederduitsch [...].
# 1791
# Holtrop, Willem
# Blussé, Abraham
# Blussé, Pieter
# Dutch language and literature
# English language and literature
#
#
#
# http://data.bibliotheken.nl/id/nbt/p413392589
# Le trésor de la langue françoise et angloise.
# 1793
# Cleef, Isaac van
# French language and literature
# English language and literature
#
#
#
# 95
# s.n.; Johnson, Thomas; ,27
# Johnson, Thomas; ,20
# Scheurleer Florisz, Hendrik; ,10
# Johnson, Thomas; s.n.; ,7
# s.n.; ,3
# Vaillant, Isaac; ,2
# s.n.; Company, the; ,2
# Chatelain, Zacharias (II); ,2
# Holtrop, Willem; Blussé, Abraham; Blussé, Pieter; ,2
# Lloyd, Owen; Scheurleer, Hendrik; ,1
# s.n.; Lintot, Bernard; Johnson, Thomas; ,1
# Duren, Johannes van (I); ,1
# Tonson, Jacob; ,1
# Johnson, Thomas; Company, the; ,1
# Wetstein, Rudolf; Smith, William; Wetstein, Jacobus; ,1
# Néaulme, Etienne; ,1
# Douci Pietersz, Adriaan; Pelt, Hendrik van; ,1
# Knyff, Abraham de; ,1
# Bosch, Jacobus; Beman, Jan Daniel; Kentlink, Hermanus; ,1
# Chatelain, Henry Jedis; ,1
# Berg, S. van den; ,1
# Melvil, J.; ,1
# Enschedé, Johannes (I); ,1
# s.n.; Gosse, Pierre Frederik; ,1
# Clement, Simon; ,1
# Leeuw, Jan de; Dekkers Mz, Johannes; ,1
# Hendriksen, Jan; ,1
# Holtrop, Willem; Eysden, Nicolaas van; Blussé, Pieter; Blussé, Abraham; ,1
# Cleef, Isaac van; ,1

# %% [markdown]
# ## Publishers

# %%
publishers = Counter()

for book in json_data:
    publ_name = ''
    for publ in book['publishers']:
        publ_name += publ['name'] + '; '
    publishers.update([publ_name])


print(count)


print('Shilder')
    
total = 0
for p,i in publishers.most_common():
    if re.search('Schilders, Richard' , p):
        print(p)
        total += i
print(total)
        
print('Giles Thorp')
    
total = 0
for p,i in publishers.most_common():
    if re.search('Thorp' , p):

        total += i
print(total)

print('Cann')

total = 0
for p,i in publishers.most_common():
    if re.search('Cann' , p):
        total += i
print(total)

print('Thomas Johnson')

total = 0
for p,i in publishers.most_common():
    if re.search('Johnson, Thomas' , p):

        total += i
print(total)

# %%
## Titles by Johnson

# %%
publishers = Counter()
count = 0

for book in json_data:

    publ_name = ''
    for publ in book['publishers']:
            publ_name += publ['name'] + '; '
            
    print(book)
            
    if re.search('Johnson, Thomas' , publ_name):
        print(f"{book['ppn']}\n{book['title']}\n{book['year']}")

# %%
df_unique = df.drop_duplicates('resource.value')
print(df_unique.query( 'year>=1450 and year<1600' ).shape)
print(df_unique.query( 'year>=1600 and year<1700' ).shape)
print(df_unique.query( 'year>=1700 and year<1800' ).shape)
print(df_unique.query( 'year>=1800' ).shape)

# %%
pre_1600 = df.query( 'year>=1450 and year<1600' )

df_grouped = pre_1600.groupby('publisher.value')['resource.value'].count()
publishers = pd.DataFrame( data = df_grouped.sort_values(ascending=False) )
publishers = publishers.reset_index()
publishers.columns = ['publisher','nr_books']

print(publishers)

# %%
62 + 693 + 307

# %%
## Can

# %%
for i,row in df.iterrows():
    imprint = row['imprint.value']
    if re.search( r'=' , str(imprint) ):
        print(row['resource.value'])
        print(row['title.value'])
        print(imprint)
